# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
file_path = 'data/monatszahlen2405_verkehrsunfaelle_export_31_05_24_r.csv'
data = pd.read_csv(file_path, usecols=['MONATSZAHL', 'AUSPRAEGUNG', 'JAHR', 'MONAT', 'WERT'])

# %%
# Rename columns to English for easier interpretation
data.columns = ['category', 'type', 'year', 'month', 'value']

# Translate category values to English
category_map = {
    "Alkoholunfälle": "alcohol",
    "Fluchtunfälle": "escape",
    "Verkehrsunfälle": "traffic"
}
data['category'] = data['category'].map(category_map)

# Translate type values to English
type_map = {
    "insgesamt": "total",
    "Verletzte und Getötete": "injured_and_killed",
    "Verletzte": "injured"
}
data['type'] = data['type'].map(type_map)

# Remove rows where month contains 'Summe'
data = data[~data['month'].astype(str).str.contains('Summe')]

# Convert month to int
data['month'] = data['month'].astype(int)

# Extract year and month from month (yyyymm format)
data['month'] = data['month'] % 100

# Impute missing values using the mean of that month of that year
data['value'] = data.groupby(['year', 'month', 'category', 'type'])['value'].transform(lambda x: x.fillna(x.mean()))

# Drop rows where the entire month-year-category-type combination has no values
data.dropna(subset=['value'], inplace=True)

# Create a date column for easier time series handling
data['date'] = pd.to_datetime(data[['year', 'month']].assign(day=1))

# Sort data by date to ensure proper time series ordering
data = data.sort_values(by='date')

# Split the data into training and testing sets
train_data = data[data['year'] <= 2020]
test_data = data[data['year'] > 2020]

# Descriptive statistics for each category and type
print("Descriptive Statistics for Each Category and Type (Training Data):")
train_data.groupby(['category', 'type'])['value'].describe()
# Out:
# Descriptive Statistics for Each Category and Type (Training Data):
#                              count         mean         std     min      25%  \
# category type
# alcohol  injured_and_killed  252.0    20.698413   10.671308     0.0    12.75
#          total               252.0    43.753968   18.069448    10.0    30.75
# escape   injured_and_killed  252.0    44.888889   14.993078    17.0    34.00
#          total               252.0   879.428571  135.216334   411.0   793.75
# traffic  injured_and_killed  252.0   511.531746  148.671149   192.0   390.50
#          total               252.0  3537.198413  479.649632  2251.0  3205.75
#
#                                 50%      75%     max
# category type
# alcohol  injured_and_killed    20.0    27.00    53.0
#          total                 40.0    53.25   107.0
# escape   injured_and_killed    43.0    55.00    85.0
#          total                877.5   966.25  1187.0
# traffic  injured_and_killed   508.0   610.25   976.0
#          total               3487.0  3906.75  4763.0

# %%
# AutoARIMA Model (Alcohol Category - Total Type)
alcohol_total_series = train_data[(train_data['category'] == 'alcohol') & (train_data['type'] == 'total')].set_index('date')['value']

# Fit AutoARIMA model
auto_arima_model = auto_arima(alcohol_total_series, seasonal=True, m=12, trace=True, error_action='ignore', suppress_warnings=True)

# Forecast for the next 12 months with AutoARIMA
auto_arima_forecast = auto_arima_model.predict(n_periods=len(test_data[(test_data['category'] == 'alcohol') & (test_data['type'] == 'total')]))

auto_arima_forecast_index = test_data[(test_data['category'] == 'alcohol') & (test_data['type'] == 'total')].set_index('date').index[:len(auto_arima_forecast)]

# Plot AutoARIMA forecast
plt.figure(figsize=(10, 6))
plt.plot(alcohol_total_series, label='Observed')
plt.plot(auto_arima_forecast_index, auto_arima_forecast, color='r', label='AutoARIMA Forecast')
plt.xlabel('Date')
plt.ylabel('Number of Accidents (Alcohol - Total)')
plt.title('AutoARIMA Forecast for Alcohol-Related Total Accidents (Next 12 Months)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=1808.071, Time=0.90 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1997.543, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1907.150, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1907.767, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1995.645, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=1852.066, Time=0.33 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=1809.773, Time=2.22 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=1809.727, Time=1.97 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=1927.066, Time=0.11 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=1865.613, Time=1.15 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=1826.206, Time=0.68 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=1811.783, Time=2.20 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=1805.988, Time=1.31 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=1884.545, Time=0.45 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1850.561, Time=0.20 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=1807.647, Time=1.23 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=1807.613, Time=1.81 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1960.127, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=1862.740, Time=0.97 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=1824.084, Time=0.76 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=1809.902, Time=2.12 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=1804.246, Time=0.41 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=1888.510, Time=0.16 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=1849.650, Time=0.14 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=1805.827, Time=0.93 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=1805.783, Time=2.10 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1938.572, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=1864.475, Time=0.72 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=1822.635, Time=0.65 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=1808.223, Time=2.18 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1806.913, Time=0.39 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=1806.035, Time=0.80 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=1804.613, Time=0.54 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=1807.989, Time=0.76 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=1802.907, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=1890.593, Time=0.12 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=1850.749, Time=0.10 sec
#  ARIMA(0,1,2)(2,0,1)[12]             : AIC=1804.513, Time=0.62 sec
#  ARIMA(0,1,2)(1,0,2)[12]             : AIC=1804.476, Time=1.10 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=1940.849, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,2)[12]             : AIC=1866.181, Time=0.78 sec
#  ARIMA(0,1,2)(2,0,0)[12]             : AIC=1822.429, Time=0.21 sec
#  ARIMA(0,1,2)(2,0,2)[12]             : AIC=inf, Time=2.79 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=1805.401, Time=0.23 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=1804.602, Time=0.46 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=1804.647, Time=0.34 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=1803.292, Time=0.17 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=1806.602, Time=0.37 sec
#
# Best model:  ARIMA(0,1,2)(1,0,1)[12]
# Total fit time: 36.958 seconds

# %%
# SARIMA Model for alcohol category with type total
sarima_model = SARIMAX(alcohol_total_series, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), enforce_stationarity=False, enforce_invertibility=False)
sarima_result = sarima_model.fit(disp=False)

# Forecast for the next 12 months with SARIMA
sarima_forecast = sarima_result.get_forecast(steps=len(test_data[(test_data['category'] == 'alcohol') & (test_data['type'] == 'total')]))
sarima_forecast_mean = sarima_forecast.predicted_mean
sarima_forecast_ci = sarima_forecast.conf_int()

# Plot SARIMA forecast
plt.figure(figsize=(10, 6))
plt.plot(alcohol_total_series, label='Observed')
plt.plot(sarima_forecast_mean.index, sarima_forecast_mean, color='r', label='SARIMA Forecast')
plt.fill_between(sarima_forecast_ci.index, sarima_forecast_ci.iloc[:, 0], sarima_forecast_ci.iloc[:, 1], color='pink', alpha=0.3)
plt.xlabel('Date')
plt.ylabel('Number of Accidents (Alcohol - Total)')
plt.title('SARIMA Forecast for Alcohol-Related Total Accidents (Next 12 Months)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# LSTM Model Preparation
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(alcohol_total_series.values.reshape(-1, 1))

# Create sequences for LSTM
sequence_length = 12
X, y = [], []
for i in range(len(scaled_data) - sequence_length):
    X.append(scaled_data[i:i + sequence_length])
    y.append(scaled_data[i + sequence_length])
X, y = np.array(X), np.array(y)

# Split into training and testing datasets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build the LSTM model
lstm_model = Sequential([
    LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    Dropout(0.2),
    LSTM(units=32, return_sequences=False),
    Dropout(0.2),
    Dense(units=1)
])

# Compile the model
lstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
lstm_model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Make predictions for the next few months
lstm_predictions = []
input_sequence = X_test[-1]  # Start with the last sequence from the test set

for _ in range(len(test_data[(test_data['category'] == 'alcohol') & (test_data['type'] == 'total')])):  # Predict for test set length
    next_value = lstm_model.predict(input_sequence.reshape(1, sequence_length, 1))
    lstm_predictions.append(next_value[0, 0])
    input_sequence = np.append(input_sequence[1:], next_value, axis=0)

# Rescale the LSTM predictions back to original scale
lstm_predictions_rescaled = scaler.inverse_transform(np.array(lstm_predictions).reshape(-1, 1))
# Out:
# 2024-11-29 18:02:33.957927: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-11-29 18:02:33.957948: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-11-29 18:02:33.957960: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-11-29 18:02:33.957975: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-29 18:02:33.957984: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 2024-11-29 18:02:35.011217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.1267
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0341
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0321
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0213
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0244
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0218
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0214
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0205
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0182
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0187
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0172
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0168
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0194
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0199
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0166
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0201
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0178
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0157
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0149
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0164
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0181
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0164
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0192
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0153
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0176
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0209
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0147
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0152
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0174
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0129
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0147
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0163
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0132
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0134
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0143
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0158
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0147
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0157
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0170
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0154
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0153
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0132
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0150
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0128
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0161
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0154
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0148
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Calculate metrics for AutoARIMA, SARIMA, and LSTM models
# Align forecast and test data
test_alcohol_total_series = test_data[(test_data['category'] == 'alcohol') & (test_data['type'] == 'total')].set_index('date')['value']
test_forecast_values_arima = auto_arima_forecast[:len(test_alcohol_total_series)]
test_forecast_values_sarima = sarima_forecast_mean[:len(test_alcohol_total_series)]
test_forecast_values_lstm = lstm_predictions_rescaled.flatten()[:len(test_alcohol_total_series)]

# Calculate metrics
mse_arima = mean_squared_error(test_alcohol_total_series, test_forecast_values_arima)
mse_sarima = mean_squared_error(test_alcohol_total_series, test_forecast_values_sarima)
mse_lstm = mean_squared_error(test_alcohol_total_series, test_forecast_values_lstm)

mae_arima = mean_absolute_error(test_alcohol_total_series, test_forecast_values_arima)
mae_sarima = mean_absolute_error(test_alcohol_total_series, test_forecast_values_sarima)
mae_lstm = mean_absolute_error(test_alcohol_total_series, test_forecast_values_lstm)

print(f'Mean Squared Error (MSE) for AutoARIMA model: {mse_arima}')
print(f'Mean Squared Error (MSE) for SARIMA model: {mse_sarima}')
print(f'Mean Squared Error (MSE) for LSTM model: {mse_lstm}')

print(f'Mean Absolute Error (MAE) for AutoARIMA model: {mae_arima}')
print(f'Mean Absolute Error (MAE) for SARIMA model: {mae_sarima}')
print(f'Mean Absolute Error (MAE) for LSTM model: {mae_lstm}')
# Out:
# Mean Squared Error (MSE) for AutoARIMA model: 91.64418863740813
# Mean Squared Error (MSE) for SARIMA model: 80.32572856907296
# Mean Squared Error (MSE) for LSTM model: 163.67390662583298
# Mean Absolute Error (MAE) for AutoARIMA model: 8.15806019607175
# Mean Absolute Error (MAE) for SARIMA model: 7.565284465090819
# Mean Absolute Error (MAE) for LSTM model: 11.100186030069986

# %%
# Plot all predictions
plt.figure(figsize=(12, 8))
plt.plot(test_alcohol_total_series.index, test_alcohol_total_series, label='Observed', color='blue')
plt.plot(auto_arima_forecast_index, test_forecast_values_arima, label='AutoARIMA Forecast', color='green')
plt.plot(test_forecast_values_sarima.index, test_forecast_values_sarima, label='SARIMA Forecast', color='red')
plt.plot(test_alcohol_total_series.index, test_forecast_values_lstm, label='LSTM Forecast', color='orange')
plt.xlabel('Date')
plt.ylabel('Number of Accidents (Alcohol - Total)')
plt.title('Forecast Comparison for Alcohol-Related Total Accidents (Next 12 Months)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# SARIMA Model outperforms all other models in terms of MSE and MAE. We will use SARIMA model for forecasting.
